# %% [markdown]
# # 이진분류 실습 : 이직 예측

# %% [markdown]
# * 회사 인사팀에서는 AIVLER 들에게 직원의 이직여부과 관련해서 분석을 요청하였습니다.
# * 최근 이직율이 증가하는 것에 대해 우려를 갖고 있기에, 이직여부에 영향을 주는 요인에 대해 분석하여, 이직할 것으로 보이는 직원들에 대해 회사를 떠나지 않도록 인사 프로그램을 준비하려고 합니다.
# * 어떤 직원이 이직할지 예측해 봅시다.

# %% [markdown]
# ![](https://adoptostaging.blob.core.windows.net/media/employee-attrition-reasons-9LIqMv.jpg)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_train_validation.CSV"
data = pd.read_csv(path)
data['Attrition'] = np.where(data['Attrition']=='Yes', 1, 0)
data.head(10)
# Out:
#    Attrition  Age     BusinessTravel              Department  \
# 0          0   33      Travel_Rarely  Research & Development
# 1          0   35  Travel_Frequently  Research & Development
# 2          0   42      Travel_Rarely  Research & Development
# 3          0   46      Travel_Rarely                   Sales
# 4          0   39  Travel_Frequently                   Sales
# 5          1   22  Travel_Frequently  Research & Development
# 6          0   24      Travel_Rarely  Research & Development
# 7          0   34      Travel_Rarely  Research & Development
# 8          0   30      Travel_Rarely  Research & Development
# 9          0   26      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                 7          3           Medical             817
# 1                18          2     Life Sciences            1412
# 2                 6          3           Medical            1911
# 3                 2          3         Marketing            1204
# 4                20          3     Life Sciences            1812
# 5                 4          1  Technical Degree             593
# 6                21          2  Technical Degree            1551
# 7                 8          3           Medical            2068
# 8                20          3             Other            1084
# 9                 6          3     Life Sciences             686
#
#    EnvironmentSatisfaction  Gender  ...  OverTime PercentSalaryHike  \
# 0                        3    Male  ...        No                11
# 1                        3    Male  ...        No                11
# 2                        3    Male  ...        No                13
# 3                        3  Female  ...        No                23
# 4                        3    Male  ...        No                18
# 5                        3    Male  ...        No                16
# 6                        3    Male  ...        No                14
# 7                        2    Male  ...        No                12
# 8                        3    Male  ...        No                15
# 9                        3  Female  ...       Yes                13
#
#    RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0                         4                0                 14
# 1                         3                0                 10
# 2                         2                1                 18
# 3                         1                0                 28
# 4                         4                1                  7
# 5                         3                0                  4
# 6                         2                3                  2
# 7                         1                0                  6
# 8                         3                1                  7
# 9                         3                1                  3
#
#    TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      3               4              13                   9
# 1                      2               3               2                   2
# 2                      3               4              13                   7
# 3                      2               3              26                  15
# 4                      6               3               2                   1
# 5                      3               3               2                   2
# 6                      3               3               1                   1
# 7                      3               4               4                   3
# 8                      1               2               6                   2
# 9                      2               3               3                   2
#
#    YearsWithCurrManager
# 0                     7
# 1                     2
# 2                     7
# 3                     9
# 4                     2
# 5                     2
# 6                     0
# 7                     2
# 8                     2
# 9                     2
#
# [10 rows x 26 columns]

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EmployeeNumber	|	사번	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	| Single, Married, Divorced		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	OverTime	|	야근여부	|	범주	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %% [markdown]
# ----

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# ### (1) 데이터 정리

# %%
target = 'Attrition'

# %%
# 불필요한 변수 제거
data.drop('EmployeeNumber', axis = 1, inplace = True)

# %%
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화
# * 범주형 데이터이면서 값이 0,1 로 되어 있는 것이 아니라면, 가변수화를 수행해야 합니다.
# * 대상이 되는 변수에 대해서 가변수화를 수행해주세요.

# %%
dum_cols = ['BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender',
            'JobRole', 'JobInvolvement', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction',
            'StockOptionLevel','WorkLifeBalance' ]

x = pd.get_dummies(x, columns = dum_cols ,drop_first = True)
x.head()
# Out:
#    Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0   33                 7          11691                   0
# 1   35                18           9362                   2
# 2   42                 6          13348                   9
# 3   46                 2          17048                   8
# 4   39                20           4127                   2
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11                 14                      3
# 1                 11                 10                      2
# 2                 13                 18                      3
# 3                 23                 28                      2
# 4                 18                  7                      6
#
#    YearsAtCompany  YearsInCurrentRole  YearsWithCurrManager  ...  \
# 0              13                   9                     7  ...
# 1               2                   2                     2  ...
# 2              13                   7                     7  ...
# 3              26                  15                     9  ...
# 4               2                   1                     2  ...
#
#    OverTime_Yes  RelationshipSatisfaction_2  RelationshipSatisfaction_3  \
# 0             0                           0                           0
# 1             0                           0                           1
# 2             0                           1                           0
# 3             0                           0                           0
# 4             0                           0                           0
#
#    RelationshipSatisfaction_4  StockOptionLevel_1  StockOptionLevel_2  \
# 0                           1                   0                   0
# 1                           0                   0                   0
# 2                           0                   1                   0
# 3                           0                   0                   0
# 4                           1                   1                   0
#
#    StockOptionLevel_3  WorkLifeBalance_2  WorkLifeBalance_3  WorkLifeBalance_4
# 0                   0                  0                  0                  1
# 1                   0                  0                  1                  0
# 2                   0                  0                  0                  1
# 3                   0                  0                  1                  0
# 4                   0                  0                  1                  0
#
# [5 rows x 53 columns]

# %% [markdown]
# ### (3) 데이터 분할
# * train_test_split :
#     * test_size : 0.# - 비율로 분할, 1보다 큰 자연수 - 갯수로 분할
#     * train_size로 지정도 가능.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 200, random_state = 2022)

# %% [markdown]
# ### (4) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %%
y_train.value_counts() / len(y_train)
# Out:
# 0    0.839048
# 1    0.160952
# Name: Attrition, dtype: float64

# %% [markdown]
# ## 4.모델링

# %% [markdown]
# ### (1) 모델1
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
n = x_train.shape[1]
n
# Out:
# 53

# %%
clear_session()

model = Sequential([Dense( 16  , input_shape = (n, )   , activation = 'relu' ),
                    Dense( 8 ,  activation = 'relu' ),
                    Dense( 4 ,  activation = 'relu'),
                    Dense( 1 , activation= 'sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                864
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 1041 (4.07 KB)
# Trainable params: 1041 (4.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile( optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
hist = model.fit( x_train, y_train, epochs = 50, validation_split= .2 ).history
# Out:
# Epoch 1/50
# 27/27 [==============================] - 3s 19ms/step - loss: 0.6992 - val_loss: 0.6371
# Epoch 2/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5882 - val_loss: 0.5334
# Epoch 3/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4971 - val_loss: 0.4446
# Epoch 4/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.4359 - val_loss: 0.3999
# Epoch 5/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4210 - val_loss: 0.3915
# Epoch 6/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4137 - val_loss: 0.3881
# Epoch 7/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4076 - val_loss: 0.3841
# Epoch 8/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4020 - val_loss: 0.3803
# Epoch 9/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3959 - val_loss: 0.3767
# Epoch 10/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3905 - val_loss: 0.3736
# Epoch 11/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3852 - val_loss: 0.3699
# Epoch 12/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3803 - val_loss: 0.3676
# Epoch 13/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.3748 - val_loss: 0.3655
# Epoch 14/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.3697 - val_loss: 0.3627
# Epoch 15/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3644 - val_loss: 0.3616
# Epoch 16/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.3589 - val_loss: 0.3596
# Epoch 17/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3535 - val_loss: 0.3555
# Epoch 18/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.3461 - val_loss: 0.3538
# Epoch 19/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3362 - val_loss: 0.3493
# Epoch 20/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.3256 - val_loss: 0.3518
# Epoch 21/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3163 - val_loss: 0.3436
# Epoch 22/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.3071 - val_loss: 0.3378
# Epoch 23/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2993 - val_loss: 0.3403
# Epoch 24/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2957 - val_loss: 0.3427
# Epoch 25/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2874 - val_loss: 0.3325
# Epoch 26/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2814 - val_loss: 0.3344
# Epoch 27/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2754 - val_loss: 0.3244
# Epoch 28/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2722 - val_loss: 0.3261
# Epoch 29/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2663 - val_loss: 0.3269
# Epoch 30/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2610 - val_loss: 0.3302
# Epoch 31/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2545 - val_loss: 0.3222
# Epoch 32/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2513 - val_loss: 0.3306
# Epoch 33/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2461 - val_loss: 0.3270
# Epoch 34/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2430 - val_loss: 0.3266
# Epoch 35/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.2387 - val_loss: 0.3318
# Epoch 36/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2377 - val_loss: 0.3498
# Epoch 37/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2307 - val_loss: 0.3280
# Epoch 38/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2269 - val_loss: 0.3259
# Epoch 39/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.2269 - val_loss: 0.3385
# Epoch 40/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2189 - val_loss: 0.3285
# Epoch 41/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.2170 - val_loss: 0.3384
# Epoch 42/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.2123 - val_loss: 0.3281
# Epoch 43/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2100 - val_loss: 0.3367
# Epoch 44/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2046 - val_loss: 0.3474
# Epoch 45/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2035 - val_loss: 0.3369
# Epoch 46/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1989 - val_loss: 0.3376
# Epoch 47/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1961 - val_loss: 0.3701
# Epoch 48/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2008 - val_loss: 0.3468
# Epoch 49/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1907 - val_loss: 0.3482
# Epoch 50/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1901 - val_loss: 0.3809

# %%
dl_history_plot(hist)

# %%
pred = model.predict(x_val)
pred = np.where( pred >= 0.5 , 1 , 0)

print(confusion_matrix(y_val, pred))
print(classification_report(y_val, pred))
# Out:
# 7/7 [==============================] - 0s 11ms/step
# [[155  14]
#  [ 13  18]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       169
#            1       0.56      0.58      0.57        31
#
#     accuracy                           0.86       200
#    macro avg       0.74      0.75      0.75       200
# weighted avg       0.87      0.86      0.87       200

# %% [markdown]
# ### (2) 모델2
# * 다양한 구조를 설계하시오. (히든레이어, 노드 수 조절)

# %%
n = x_train.shape[1]
n
# Out:
# 53

# %%
clear_session()

model = Sequential([Dense( 16  , input_shape = (n, )   , activation = 'relu' ),
                    Dense( 8 ,  activation = 'relu' ),
                    Dense( 4 ,  activation = 'relu'),
                    Dense( 1 , activation= 'sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                864
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 1041 (4.07 KB)
# Trainable params: 1041 (4.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile( optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
hist = model.fit( x_train, y_train, epochs = 50, validation_split= .2 ).history
# Out:
# Epoch 1/50
# 27/27 [==============================] - 3s 19ms/step - loss: 0.6992 - val_loss: 0.6371
# Epoch 2/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.5882 - val_loss: 0.5334
# Epoch 3/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4971 - val_loss: 0.4446
# Epoch 4/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.4359 - val_loss: 0.3999
# Epoch 5/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4210 - val_loss: 0.3915
# Epoch 6/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4137 - val_loss: 0.3881
# Epoch 7/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4076 - val_loss: 0.3841
# Epoch 8/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4020 - val_loss: 0.3803
# Epoch 9/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3959 - val_loss: 0.3767
# Epoch 10/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3905 - val_loss: 0.3736
# Epoch 11/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3852 - val_loss: 0.3699
# Epoch 12/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3803 - val_loss: 0.3676
# Epoch 13/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.3748 - val_loss: 0.3655
# Epoch 14/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.3697 - val_loss: 0.3627
# Epoch 15/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3644 - val_loss: 0.3616
# Epoch 16/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.3589 - val_loss: 0.3596
# Epoch 17/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3535 - val_loss: 0.3555
# Epoch 18/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.3461 - val_loss: 0.3538
# Epoch 19/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3362 - val_loss: 0.3493
# Epoch 20/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.3256 - val_loss: 0.3518
# Epoch 21/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3163 - val_loss: 0.3436
# Epoch 22/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.3071 - val_loss: 0.3378
# Epoch 23/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2993 - val_loss: 0.3403
# Epoch 24/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2957 - val_loss: 0.3427
# Epoch 25/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.2874 - val_loss: 0.3325
# Epoch 26/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2814 - val_loss: 0.3344
# Epoch 27/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2754 - val_loss: 0.3244
# Epoch 28/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2722 - val_loss: 0.3261
# Epoch 29/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2663 - val_loss: 0.3269
# Epoch 30/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2610 - val_loss: 0.3302
# Epoch 31/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2545 - val_loss: 0.3222
# Epoch 32/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2513 - val_loss: 0.3306
# Epoch 33/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2461 - val_loss: 0.3270
# Epoch 34/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2430 - val_loss: 0.3266
# Epoch 35/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.2387 - val_loss: 0.3318
# Epoch 36/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2377 - val_loss: 0.3498
# Epoch 37/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2307 - val_loss: 0.3280
# Epoch 38/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2269 - val_loss: 0.3259
# Epoch 39/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.2269 - val_loss: 0.3385
# Epoch 40/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2189 - val_loss: 0.3285
# Epoch 41/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.2170 - val_loss: 0.3384
# Epoch 42/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.2123 - val_loss: 0.3281
# Epoch 43/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2100 - val_loss: 0.3367
# Epoch 44/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2046 - val_loss: 0.3474
# Epoch 45/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.2035 - val_loss: 0.3369
# Epoch 46/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1989 - val_loss: 0.3376
# Epoch 47/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1961 - val_loss: 0.3701
# Epoch 48/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2008 - val_loss: 0.3468
# Epoch 49/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1907 - val_loss: 0.3482
# Epoch 50/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1901 - val_loss: 0.3809

# %%
dl_history_plot(hist)

# %%
pred = model.predict(x_val)
pred = np.where( pred >= 0.5 , 1 , 0)

print(confusion_matrix(y_val, pred))
print(classification_report(y_val, pred))
# Out:
# 7/7 [==============================] - 0s 11ms/step
# [[155  14]
#  [ 13  18]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       169
#            1       0.56      0.58      0.57        31
#
#     accuracy                           0.86       200
#    macro avg       0.74      0.75      0.75       200
# weighted avg       0.87      0.86      0.87       200
